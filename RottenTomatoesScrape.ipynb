# %%
import requests
from bs4 import BeautifulSoup
from IPython.display import HTML

# %%
snapshot_url = 'https://www.rottentomatoes.com/m/wonder_woman_1984/reviews'

# %%
snapshot = requests.get(snapshot_url)
snapshot
# Out:
# <Response [200]>

# %%
raw_html = snapshot.text

# %%
soup = BeautifulSoup(raw_html, 'html.parser')

# %%
import re

# %%
a=re.findall('review text', raw_html)

# %%
a
# Out:
# []

# %%
a.p
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/n_/55jfz6s520106t4htl9vcq740000gn/T/ipykernel_27670/1438661555.py in <module>
# ----> 1 a.p
#
# AttributeError: 'list' object has no attribute 'p'

# %%
soup.p
# Out:
# <p class="cognito-signup-form-help" slot="help">
# <a data-qa="auth-signup-screen-reset-client-link" href="/reset-client">Trouble logging in?</a>
# </p>

# %%
soup.p['class']
# Out:
# ['cognito-signup-form-help']

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html dir="ltr" lang="en" prefix="fb: http://www.facebook.com/2008/fbml og: http://opengraphprotocol.org/schema/" xmlns="http://www.w3.org/1999/xhtml">
# <head prefix="og: http://ogp.me/ns# flixstertomatoes: http://ogp.me/ns/apps/flixstertomatoes#">
# <script charset="UTF-8" crossorigin="anonymous" data-domain-script="7e979733-6841-4fce-9182-515fac69187f" integrity="sha384-WEHwEli88wqOiQd913F1utFZiwisa8XhCkbjLnbKEpFa/WbFcPKeGg7h4fdsv0Z/" src="https://cdn.cookielaw.org/consent/7e979733-6841-4fce-9182-515fac69187f/otSDKStub.js" type="text/javascript">
# </script>
# <script type="text/javascript">
#         function OptanonWrapper() { }
#         </script>
# <script ccpa-opt-out-geo="US" ccpa-opt-out-ids="dummy" ccpa-opt-out-lspa="false" charset="UTF-8" src="https://cdn.cookielaw.org/opt-out/otCCPAiab.js" type="text/javascript">
# </script>
# <script src="/assets/pizza-pie/javascripts/bundles/roma/rt-common.js?single"></script>
# ...

# %%
soup.find_all('p')
# Out:
# [<p class="cognito-signup-form-help" slot="help">
#  <a data-qa="auth-signup-screen-reset-client-link" href="/reset-client">Trouble logging in?</a>
#  </p>,
#  <p class="cognito-signup-form__terms-and-policies" slot="terms-and-policies">
#          By continuing, you agree to the <a data-qa="auth-signup-screen-privacy-policy-link" href="https://www.fandango.com/policies/privacy-policy" rel="noopener" target="_blank">Privacy Policy</a> and
#          the <a data-qa="auth-signup-screen-terms-policies-link" href="https://www.fandango.com/policies/terms-and-policies" rel="noopener" target="_blank">Terms and Policies</a>, and to receive email from Rotten Tomatoes.
#      </p>,
#  <p class="cognito-signup-form__terms-and-policies" slot="termsAndPolicies">
#        By creating an account, you agree to the
#        <a data-qa="auth-name-screen-privacy-policy-link" href="https://www.fandango.com/policies/privacy-policy" rel="noopener" target="_blank"> Privacy Policy </a>
# ...

# %%
a=soup.find_all('p')

# %%
a
# Out:
# [<p class="cognito-signup-form-help" slot="help">
#  <a data-qa="auth-signup-screen-reset-client-link" href="/reset-client">Trouble logging in?</a>
#  </p>,
#  <p class="cognito-signup-form__terms-and-policies" slot="terms-and-policies">
#          By continuing, you agree to the <a data-qa="auth-signup-screen-privacy-policy-link" href="https://www.fandango.com/policies/privacy-policy" rel="noopener" target="_blank">Privacy Policy</a> and
#          the <a data-qa="auth-signup-screen-terms-policies-link" href="https://www.fandango.com/policies/terms-and-policies" rel="noopener" target="_blank">Terms and Policies</a>, and to receive email from Rotten Tomatoes.
#      </p>,
#  <p class="cognito-signup-form__terms-and-policies" slot="termsAndPolicies">
#        By creating an account, you agree to the
#        <a data-qa="auth-name-screen-privacy-policy-link" href="https://www.fandango.com/policies/privacy-policy" rel="noopener" target="_blank"> Privacy Policy </a>
# ...

# %%
soup.find_all('<div class=\"the_review\" data-qa=\"review-text\">[;a-zA-Z\s,-.\'\/\?\[\]\":\']*</div>')
# Out:
# []

# %%
soup
# Out:
# '<!DOCTYPE html>\n\n<html dir="ltr" lang="en" prefix="fb: http://www.facebook.com/2008/fbml og: http://opengraphprotocol.org/schema/" xmlns="http://www.w3.org/1999/xhtml">\n<head prefix="og: http://ogp.me/ns# flixstertomatoes: http://ogp.me/ns/apps/flixstertomatoes#">\n<script charset="UTF-8" crossorigin="anonymous" data-domain-script="7e979733-6841-4fce-9182-515fac69187f" integrity="sha384-WEHwEli88wqOiQd913F1utFZiwisa8XhCkbjLnbKEpFa/WbFcPKeGg7h4fdsv0Z/" src="https://cdn.cookielaw.org/consent/7e979733-6841-4fce-9182-515fac69187f/otSDKStub.js" type="text/javascript">\n</script>\n<script type="text/javascript">\n        function OptanonWrapper() { }\n        </script>\n<script ccpa-opt-out-geo="US" ccpa-opt-out-ids="dummy" ccpa-opt-out-lspa="false" charset="UTF-8" src="https://cdn.cookielaw.org/opt-out/otCCPAiab.js" type="text/javascript">\n</script>\n<script src="/assets/pizza-pie/javascripts/bundles/roma/rt-common.js?single"></script>\n<meta content="text/html; charset=utf-8" http-e
# ...

# %%
soup.find_all('a')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/n_/55jfz6s520106t4htl9vcq740000gn/T/ipykernel_27670/3561481807.py in <module>
# ----> 1 soup.find_all('a')
#
# AttributeError: 'str' object has no attribute 'find_all'

# %%
soup = BeautifulSoup(raw_html, 'html.parser')

# %%
soup.find_all('p')
# Out:
# [<p class="cognito-signup-form-help" slot="help">
#  <a data-qa="auth-signup-screen-reset-client-link" href="/reset-client">Trouble logging in?</a>
#  </p>,
#  <p class="cognito-signup-form__terms-and-policies" slot="terms-and-policies">
#          By continuing, you agree to the <a data-qa="auth-signup-screen-privacy-policy-link" href="https://www.fandango.com/policies/privacy-policy" rel="noopener" target="_blank">Privacy Policy</a> and
#          the <a data-qa="auth-signup-screen-terms-policies-link" href="https://www.fandango.com/policies/terms-and-policies" rel="noopener" target="_blank">Terms and Policies</a>, and to receive email from Rotten Tomatoes.
#      </p>,
#  <p class="cognito-signup-form__terms-and-policies" slot="termsAndPolicies">
#        By creating an account, you agree to the
#        <a data-qa="auth-name-screen-privacy-policy-link" href="https://www.fandango.com/policies/privacy-policy" rel="noopener" target="_blank"> Privacy Policy </a>
# ...

# %%
data_soup = BeautifulSoup('<p class="review-text" data-q="review-quote">foo!</p>', 'html.parser')

# %%
data_soup
# Out:
# <p class="review-text" data-q="review-quote">foo!</p>

# %%
soup.find_all(attrs={"data-qa": "review-quote"})
# Out:
# []

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html dir="ltr" lang="en" prefix="fb: http://www.facebook.com/2008/fbml og: http://opengraphprotocol.org/schema/" xmlns="http://www.w3.org/1999/xhtml">
# <head prefix="og: http://ogp.me/ns# flixstertomatoes: http://ogp.me/ns/apps/flixstertomatoes#">
# <script charset="UTF-8" crossorigin="anonymous" data-domain-script="7e979733-6841-4fce-9182-515fac69187f" integrity="sha384-WEHwEli88wqOiQd913F1utFZiwisa8XhCkbjLnbKEpFa/WbFcPKeGg7h4fdsv0Z/" src="https://cdn.cookielaw.org/consent/7e979733-6841-4fce-9182-515fac69187f/otSDKStub.js" type="text/javascript">
# </script>
# <script type="text/javascript">
#         function OptanonWrapper() { }
#         </script>
# <script ccpa-opt-out-geo="US" ccpa-opt-out-ids="dummy" ccpa-opt-out-lspa="false" charset="UTF-8" src="https://cdn.cookielaw.org/opt-out/otCCPAiab.js" type="text/javascript">
# </script>
# <script src="/assets/pizza-pie/javascripts/bundles/roma/rt-common.js?single"></script>
# ...

# %%
data_soup = BeautifulSoup('<p class="review-text" data-q="review-quote">', 'html.parser')

# %%
data_soup
# Out:
# <p class="review-text" data-q="review-quote"></p>

# %%
soup.find_all("review-quote")
# Out:
# []

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en" prefix="fb: http://www.facebook.com/2008/fbml og: http://opengraphprotocol.org/schema/" xmlns="http://www.w3.org/1999/xhtml">
#  <head prefix="og: http://ogp.me/ns# flixstertomatoes: http://ogp.me/ns/apps/flixstertomatoes#">
#   <script charset="UTF-8" crossorigin="anonymous" data-domain-script="7e979733-6841-4fce-9182-515fac69187f" integrity="sha384-WEHwEli88wqOiQd913F1utFZiwisa8XhCkbjLnbKEpFa/WbFcPKeGg7h4fdsv0Z/" src="https://cdn.cookielaw.org/consent/7e979733-6841-4fce-9182-515fac69187f/otSDKStub.js" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    function OptanonWrapper() { }
#   </script>
#   <script ccpa-opt-out-geo="US" ccpa-opt-out-ids="dummy" ccpa-opt-out-lspa="false" charset="UTF-8" src="https://cdn.cookielaw.org/opt-out/otCCPAiab.js" type="text/javascript">
#   </script>
#   <script src="/assets/pizza-pie/javascripts/bundles/roma/rt-common.js?single">
#   </script>
# ...

# %%
import re

for line in soup:
    line = line.rstrip()
    if re.search('<p class="review-text" data-q="review-quote">[.*]</p>',line):
        print(line)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/n_/55jfz6s520106t4htl9vcq740000gn/T/ipykernel_27670/2617414435.py in <module>
#       2
#       3 for line in soup:
# ----> 4     line = line.rstrip()
#       5     if re.search('<p class="review-text" data-q="review-quote">[.*]</p>',line):
#       6         print(line)
#
# TypeError: 'NoneType' object is not callable

# %%
raw_html
# Out:
# '<!DOCTYPE html>\n<html lang="en" dir="ltr" xmlns="http://www.w3.org/1999/xhtml" prefix="fb: http://www.facebook.com/2008/fbml og: http://opengraphprotocol.org/schema/">\n    <head prefix="og: http://ogp.me/ns# flixstertomatoes: http://ogp.me/ns/apps/flixstertomatoes#">\n        \n        <script src="https://cdn.cookielaw.org/consent/7e979733-6841-4fce-9182-515fac69187f/otSDKStub.js"\n            type="text/javascript"\n            charset="UTF-8"\n            data-domain-script="7e979733-6841-4fce-9182-515fac69187f"\n            integrity="sha384-WEHwEli88wqOiQd913F1utFZiwisa8XhCkbjLnbKEpFa/WbFcPKeGg7h4fdsv0Z/"\n            crossorigin="anonymous">\n        </script>\n        <script type="text/javascript">\n        function OptanonWrapper() { }\n        </script>\n        \n        \n        <script src="https://cdn.cookielaw.org/opt-out/otCCPAiab.js"\n            type="text/javascript"\n            charset="UTF-8"\n            ccpa-opt-out-ids="dummy"\n            ccpa-opt-out-ge
# ...

# %%
re.findall('quote">(.+)</p>', raw_html)
# Out:
# ['While it did have its problems&#44; and while it may have had a different version of Wonder Woman that people may be used to from the first film&#44; it was well made&#44; and there&apos;s a lot to like about it&#46;',
#  "A terrible fiasco that can't rise from beneath even with the female empowerment that it seeks to reflect. [Full review in Spanish]",
#  'In each clumsy chapter, the film chooses the easy way ignoring development and transformation, and instead, throwing up Manichaeisms to avoid depth... [Full review in Spanish]',
#  'Wonder Woman 1984 is the bombastic&#44; big-hearted blockbuster we need after the terrors of 2020&#44; even if it can&#8217;t quite surpass its subversive predecessor&#46;',
#  'I still think Gal Gadot is some of the best casting in the entire superhero genre&#46; She carries the movie with an effortless grace&#46; It&#8217;s some of the moving parts and the shaky structure around her that unavoidably leaves this feeling like a letdown&#46;',
# ...

# %%
soup = BeautifulSoup(raw_html, 'html.parser')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en" prefix="fb: http://www.facebook.com/2008/fbml og: http://opengraphprotocol.org/schema/" xmlns="http://www.w3.org/1999/xhtml">
#  <head prefix="og: http://ogp.me/ns# flixstertomatoes: http://ogp.me/ns/apps/flixstertomatoes#">
#   <script charset="UTF-8" crossorigin="anonymous" data-domain-script="7e979733-6841-4fce-9182-515fac69187f" integrity="sha384-WEHwEli88wqOiQd913F1utFZiwisa8XhCkbjLnbKEpFa/WbFcPKeGg7h4fdsv0Z/" src="https://cdn.cookielaw.org/consent/7e979733-6841-4fce-9182-515fac69187f/otSDKStub.js" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    function OptanonWrapper() { }
#   </script>
#   <script ccpa-opt-out-geo="US" ccpa-opt-out-ids="dummy" ccpa-opt-out-lspa="false" charset="UTF-8" src="https://cdn.cookielaw.org/opt-out/otCCPAiab.js" type="text/javascript">
#   </script>
#   <script src="/assets/pizza-pie/javascripts/bundles/roma/rt-common.js?single">
#   </script>
# ...

# %%
raw_html
# Out:
# '<!DOCTYPE html>\n<html lang="en" dir="ltr" xmlns="http://www.w3.org/1999/xhtml" prefix="fb: http://www.facebook.com/2008/fbml og: http://opengraphprotocol.org/schema/">\n    <head prefix="og: http://ogp.me/ns# flixstertomatoes: http://ogp.me/ns/apps/flixstertomatoes#">\n        \n        <script src="https://cdn.cookielaw.org/consent/7e979733-6841-4fce-9182-515fac69187f/otSDKStub.js"\n            type="text/javascript"\n            charset="UTF-8"\n            data-domain-script="7e979733-6841-4fce-9182-515fac69187f"\n            integrity="sha384-WEHwEli88wqOiQd913F1utFZiwisa8XhCkbjLnbKEpFa/WbFcPKeGg7h4fdsv0Z/"\n            crossorigin="anonymous">\n        </script>\n        <script type="text/javascript">\n        function OptanonWrapper() { }\n        </script>\n        \n        \n        <script src="https://cdn.cookielaw.org/opt-out/otCCPAiab.js"\n            type="text/javascript"\n            charset="UTF-8"\n            ccpa-opt-out-ids="dummy"\n            ccpa-opt-out-ge
# ...

# %%
b=re.findall('quote">(.+)</p>', raw_html)

# %%
print(b.prettify())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/n_/55jfz6s520106t4htl9vcq740000gn/T/ipykernel_27670/412537275.py in <module>
# ----> 1 print(b.prettify())
#
# AttributeError: 'list' object has no attribute 'prettify'

# %%
s2 = BeautifulSoup(b, 'html.parser')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/n_/55jfz6s520106t4htl9vcq740000gn/T/ipykernel_27670/2381865930.py in <module>
# ----> 1 s2 = BeautifulSoup(b, 'html.parser')
#
# ~/opt/anaconda3/lib/python3.8/site-packages/bs4/__init__.py in __init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
#     324         rejections = []
#     325         success = False
# --> 326         for (self.markup, self.original_encoding, self.declared_html_encoding,
#     327          self.contains_replacement_characters) in (
#     328              self.builder.prepare_markup(
#
# ~/opt/anaconda3/lib/python3.8/site-packages/bs4/builder/_htmlparser.py in prepare_markup(self, markup, user_specified_encoding, document_declared_encoding, exclude_encodings)
#     378
# ...

# %%
b[0]
# Out:
# 'While it did have its problems&#44; and while it may have had a different version of Wonder Woman that people may be used to from the first film&#44; it was well made&#44; and there&apos;s a lot to like about it&#46;'

# %%
BeautifulSoup(b[0],'html.parser')
# Out:
# While it did have its problems, and while it may have had a different version of Wonder Woman that people may be used to from the first film, it was well made, and there's a lot to like about it.

# %%
len(b)
# Out:
# 20

# %%
snapshot2 = requests.get(snapshot_url.format(2))
snapshot2
# Out:
# <Response [200]>

# %%
raw_html2 = snapshot2.text

# %%
re.findall('quote">(.+)</p>', raw_html2)
# Out:
# ['While it did have its problems&#44; and while it may have had a different version of Wonder Woman that people may be used to from the first film&#44; it was well made&#44; and there&apos;s a lot to like about it&#46;',
#  "A terrible fiasco that can't rise from beneath even with the female empowerment that it seeks to reflect. [Full review in Spanish]",
#  'In each clumsy chapter, the film chooses the easy way ignoring development and transformation, and instead, throwing up Manichaeisms to avoid depth... [Full review in Spanish]',
#  'Wonder Woman 1984 is the bombastic&#44; big-hearted blockbuster we need after the terrors of 2020&#44; even if it can&#8217;t quite surpass its subversive predecessor&#46;',
#  'I still think Gal Gadot is some of the best casting in the entire superhero genre&#46; She carries the movie with an effortless grace&#46; It&#8217;s some of the moving parts and the shaky structure around her that unavoidably leaves this feeling like a letdown&#46;',
# ...

# %%
snapshot3 = requests.get(snapshot_url.format(4))
snapshot3
# Out:
# <Response [200]>

# %%
raw_html3 = snapshot3.text

# %%
re.findall('quote">(.+)</p>', raw_html3)
# Out:
# ['While it did have its problems&#44; and while it may have had a different version of Wonder Woman that people may be used to from the first film&#44; it was well made&#44; and there&apos;s a lot to like about it&#46;',
#  "A terrible fiasco that can't rise from beneath even with the female empowerment that it seeks to reflect. [Full review in Spanish]",
#  'In each clumsy chapter, the film chooses the easy way ignoring development and transformation, and instead, throwing up Manichaeisms to avoid depth... [Full review in Spanish]',
#  'Wonder Woman 1984 is the bombastic&#44; big-hearted blockbuster we need after the terrors of 2020&#44; even if it can&#8217;t quite surpass its subversive predecessor&#46;',
#  'I still think Gal Gadot is some of the best casting in the entire superhero genre&#46; She carries the movie with an effortless grace&#46; It&#8217;s some of the moving parts and the shaky structure around her that unavoidably leaves this feeling like a letdown&#46;',
# ...

# %%
url = 'https://www.rottentomatoes.com/m/wonder_woman_1984/reviews'.format(2)

# %%
s1= requests.get(url)

# %%
raw=s1.text

# %%
re.findall('quote">(.+)</p>', raw)
# Out:
# ['While it did have its problems&#44; and while it may have had a different version of Wonder Woman that people may be used to from the first film&#44; it was well made&#44; and there&apos;s a lot to like about it&#46;',
#  "A terrible fiasco that can't rise from beneath even with the female empowerment that it seeks to reflect. [Full review in Spanish]",
#  'In each clumsy chapter, the film chooses the easy way ignoring development and transformation, and instead, throwing up Manichaeisms to avoid depth... [Full review in Spanish]',
#  'Wonder Woman 1984 is the bombastic&#44; big-hearted blockbuster we need after the terrors of 2020&#44; even if it can&#8217;t quite surpass its subversive predecessor&#46;',
#  'I still think Gal Gadot is some of the best casting in the entire superhero genre&#46; She carries the movie with an effortless grace&#46; It&#8217;s some of the moving parts and the shaky structure around her that unavoidably leaves this feeling like a letdown&#46;',
# ...

# %%
h=re.findall('quote">(.+)</p>', raw)
h
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/n_/55jfz6s520106t4htl9vcq740000gn/T/ipykernel_14324/3033867135.py in <module>
# ----> 1 h=re.findall('quote">(.+)</p>', raw)
#       2 h
#
# NameError: name 'raw' is not defined
